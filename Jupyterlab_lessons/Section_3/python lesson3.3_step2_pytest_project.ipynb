# %%
# Берем тесты из шага — https://stepik.org/lesson/138920/step/11?unit=196194
# Создайм новый файл
import PyTest

# Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом
# Перепишите в стиле unittest тест для страницы http://suninjuly.github.io/registration1.html
class test_class_name(unittest.TestCase):
    def test_class_name1(self):
# Оформите финальные проверки в тестах в стиле unittest, например, используя проверочный метод assertEqual
        self.assertEqual
        "Congratulations! You have successfully registered!" == welcome_text


if __name__ == "__main__":
    unittest.main()
    print("All tests passed!")
    
    link = "http://suninjuly.github.io/registration1.html"
    browser = webdriver.Chrome()
    browser.get(link)
    
# Код, который заполняет обязательные поля  
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")

# Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

# с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта

# Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом      
# Перепишите в стиле unittest второй тест для страницы http://suninjuly.github.io/registration2.html
class test_class_name(unittest.TestCase):
    def test_class_name2(self):
# Оформите финальные проверки в тестах в стиле unittest, например, используя проверочный метод assertEqual
        self.assertEqual
        "Congratulations! You have successfully registered!" == welcome_text


if __name__ == "__main__":
    unittest.main()
    print("All tests passed!")
        
    link = "http://suninjuly.github.io/registration2.html"
    browser = webdriver.Chrome()
    browser.get(link)

    # Код, который заполняет обязательные поля
    
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")
    
    # Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

# с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта

# Запустите получившиеся тесты из файла 
# Просмотрите отчёт о запуске и найдите последнюю строчку
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-5a8223747089> in <module>
#       1 # Берем тесты из шага — https://stepik.org/lesson/138920/step/11?unit=196194
#       2 # Создайм новый файл
# ----> 3 import PyTest
#       4
#       5 # Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом
#
# ModuleNotFoundError: No module named 'PyTest'

# %%
pip install pytest==7.1.2
# Out:
# Requirement already satisfied: pytest==7.1.2 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (7.1.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (1.0.0)
# Requirement already satisfied: iniconfig in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (1.1.1)
# Requirement already satisfied: tomli>=1.0.0 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (1.11.0)
# Requirement already satisfied: atomicwrites>=1.0 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (1.4.1)
# Requirement already satisfied: colorama in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (0.4.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (20.3.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: packaging in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from pytest==7.1.2) (20.8)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages (from packaging->pytest==7.1.2) (2.4.7)

# %%
# Берем тесты из шага — https://stepik.org/lesson/138920/step/11?unit=196194
# Создайм новый файл
import PyTest

# Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом
# Перепишите в стиле unittest тест для страницы http://suninjuly.github.io/registration1.html
class test_class_name(unittest.TestCase):
    def test_class_name1(self):
# Оформите финальные проверки в тестах в стиле unittest, например, используя проверочный метод assertEqual
        self.assertEqual
        "Congratulations! You have successfully registered!" == welcome_text


if __name__ == "__main__":
    unittest.main()
    print("All tests passed!")
    
    link = "http://suninjuly.github.io/registration1.html"
    browser = webdriver.Chrome()
    browser.get(link)
    
# Код, который заполняет обязательные поля  
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")

# Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

# с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта

# Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом      
# Перепишите в стиле unittest второй тест для страницы http://suninjuly.github.io/registration2.html
class test_class_name(unittest.TestCase):
    def test_class_name2(self):
# Оформите финальные проверки в тестах в стиле unittest, например, используя проверочный метод assertEqual
        self.assertEqual
        "Congratulations! You have successfully registered!" == welcome_text


if __name__ == "__main__":
    unittest.main()
    print("All tests passed!")
        
    link = "http://suninjuly.github.io/registration2.html"
    browser = webdriver.Chrome()
    browser.get(link)

    # Код, который заполняет обязательные поля
    
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")
    
    # Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

# с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта

# Запустите получившиеся тесты из файла 
# Просмотрите отчёт о запуске и найдите последнюю строчку
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-78cee4c4ff03> in <module>
#       1 # Берем тесты из шага — https://stepik.org/lesson/138920/step/11?unit=196194
#       2 # Создайм новый файл
# ----> 3 import PyTest
#       4
#       5 # Создаем в нем класс с тестами, который должен наследоваться от unittest.TestCase по аналогии с предыдущим шагом
#
# ModuleNotFoundError: No module named 'PyTest'
