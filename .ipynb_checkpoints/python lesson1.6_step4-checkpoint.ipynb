# %%
from selenium import webdriver
import time 


link = "http://suninjuly.github.io/simple_form_find_task.html"

try:
    browser = webdriver.Chrome()
    browser.get(link)

    input1 = browser.find_element_by_tag_name("input")
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_name("last_name")
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_class_name("city")
    input3.send_keys("Smolensk")
    input4 = browser.find_element_by_id("country")
    input4.send_keys("Russia")
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

finally:
    # успеваем скопировать код за 30 секунд
    time.sleep(30)
    # закрываем браузер после всех манипуляций
    browser.quit()

# не забываем оставить пустую строку в конце файла
# Out:
# <ipython-input-4-1bef2b2bc901>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_tag_name("input")
# <ipython-input-4-1bef2b2bc901>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input2 = browser.find_element_by_name("last_name")
# <ipython-input-4-1bef2b2bc901>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input3 = browser.find_element_by_class_name("city")
# <ipython-input-4-1bef2b2bc901>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input4 = browser.find_element_by_id("country")
# <ipython-input-4-1bef2b2bc901>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = browser.find_element_by_css_selector("button.btn")

# %%
from selenium import webdriver
import math
browser = webdriver.Chrome()
link = browser.find_element_by_link_text("find_link_text_redirect1.html")
# Out:
# <ipython-input-20-739cb6b7c767>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link = browser.find_element_by_link_text("find_link_text_redirect1.html")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-20-739cb6b7c767> in <module>
#       2 import math
#       3 browser = webdriver.Chrome()
# ----> 4 link = browser.find_element_by_link_text("find_link_text_redirect1.html")
#
# c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_link_text(self, link_text)
#     566             stacklevel=2,
#     567         )
# --> 568         return self.find_element(by=By.LINK_TEXT, value=link_text)
#     569
#     570     def find_elements_by_link_text(self, text) -> WebElement:
#
# ...

# %%
from selenium import webdriver
browser = webdriver.Chrome()
browser.get("http://suninjuly.github.io/find_link_text")
link = browser.find_element_by_link_text(str(math.ceil(math.pow(math.pi, math.e)*10000)))
link.click()

try:
    input1 = browser.find_element_by_tag_name("input")
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_name("last_name")
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_class_name("city")
    input3.send_keys("Smolensk")
    input4 = browser.find_element_by_id("country")
    input4.send_keys("Russia")
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

finally:
    # успеваем скопировать код за 30 секунд
    time.sleep(30)
    # закрываем браузер после всех манипуляций
    browser.quit()

# не забываем оставить пустую строку в конце файла
# Out:
# <ipython-input-15-77f108d74ce7>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   link = browser.find_element_by_link_text(str(math.ceil(math.pow(math.pi, math.e)*10000)))
# <ipython-input-15-77f108d74ce7>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_tag_name("input")
# <ipython-input-15-77f108d74ce7>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input2 = browser.find_element_by_name("last_name")
# <ipython-input-15-77f108d74ce7>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input3 = browser.find_element_by_class_name("city")
# <ipython-input-15-77f108d74ce7>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input4 = browser.find_element_by_id("country")
# ...

# %%
# подготовка для теста
# открываем страницу первого товара
# данный сайт не существует, этот код приведен только для примера
from selenium import webdriver
import math
browser = webdriver.Chrome()
browser.get("https://fake-shop.com/book1.html")
link.click()
# добавляем товар в корзину
add_button = browser.find_element_by_css_selector(".add")
add_button.click()
# открываем страницу второго товара
browser.get("https://fake-shop.com/book2.html")
# добавляем товар в корзину
add_button = browser.find_element_by_css_selector(".add")
add_button.click()
# тестовый сценарий
# открываем корзину
browser.get("https://fake-shop.com/basket.html")
# ищем все добавленные товары
goods = browser.find_elements_by_css_selector(".good")
# проверяем, что количество товаров равно 2
assert len(goods) == 2
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-19-a20a398642e9> in <module>
#       5 import math
#       6 browser = webdriver.Chrome()
# ----> 7 browser.get("https://fake-shop.com/book1.html")
#       8 link.click()
#       9 # добавляем товар в корзину
#
# c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     434         Loads a web page in the current browser session.
#     435         """
# --> 436         self.execute(Command.GET, {'url': url})
#     437
#     438     @property
#
# c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
# ...

# %%
from selenium import webdriver
import time

try:
    browser = webdriver.Chrome()
    browser.get("http://suninjuly.github.io/huge_form.html")
    
    input1 = browser.find_element_by_class_name("first")
    input1.send_keys("Ivanov")
    input2 = browser.find_element_by_class_name("second")
    input2.send_keys("Ivan")
    input3 = browser.find_element_by_class_name("third")
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_css_selector("input:nth-child(11)")
    input4.send_keys("Russia")
    input5 = browser.find_element_by_css_selector("input:nth-child(14)")
    input5.send_keys("Moscow")
    input6 = browser.find_element_by_css_selector("input:nth-child(17)")
    input6.send_keys("Magistralnaya")
    input7 = browser.find_element_by_css_selector("input:nth-child(20)")
    input7.send_keys("Cat")
    input8 = browser.find_element_by_css_selector("input:nth-child(23)")
    input8.send_keys("Star Wars")
    input9 = browser.find_element_by_css_selector("input:nth-child(26)")
    input9.send_keys("Nick Patterson")
    input10 = browser.find_element_by_css_selector("input:nth-child(29)")
    input10.send_keys("Talking Heads Drum Playthrough")
    input11 = browser.find_element_by_css_selector("input:nth-child(32)")
    input11.send_keys("Hyundai")
    input12 = browser.find_element_by_css_selector("input:nth-child(35)")
    input12.send_keys("Drammer")
    input13 = browser.find_element_by_css_selector("input:nth-child(38)")
    input13.send_keys("The Two Dianas")
    input14 = browser.find_element_by_css_selector("input:nth-child(41)")
    input14.send_keys("Rugby ")
    input15 = browser.find_element_by_css_selector("input:nth-child(44)")
    input15.send_keys("Play computer games")
    input16 = browser.find_element_by_css_selector("input:nth-child(47)")
    input16.send_keys("I do")
    input17 = browser.find_element_by_css_selector("input:nth-child(50)")
    input17.send_keys("Not like")
    input18 = browser.find_element_by_css_selector("input:nth-child(53)")
    input18.send_keys("Im 33 years old")
    input19 = browser.find_element_by_css_selector("input:nth-child(56)")
    input19.send_keys("2 positive")
    input20 = browser.find_element_by_css_selector("input:nth-child(59)")
    input20.send_keys("Blue")
    input21 = browser.find_element_by_css_selector("input:nth-child(62)")
    input21.send_keys("Pizza")
    input22 = browser.find_element_by_css_selector("input:nth-child(65)")
    input22.send_keys("Tiramisu")
    input23 = browser.find_element_by_css_selector("input:nth-child(68)")
    input23.send_keys("Mustorg")
    input24 = browser.find_element_by_css_selector("input:nth-child(71)")
    input24.send_keys("Echo")
    input25 = browser.find_element_by_css_selector("input:nth-child(74)")
    input25.send_keys("Mads Dittmann Mikkelsen")
    input26 = browser.find_element_by_css_selector("input:nth-child(77)")
    input26.send_keys("Scarlett Johansson")
           
    elements = browser.find_elements_by_tag_name("input")
    for element in elements:
        element.send_keys("Answer")
    
    button = browser.find_element_by_css_selector("button.btn")
    button.click()
    
finally:
    # успеваем скопировать код за 30 секунд
    time.sleep(30)
    # закрываем браузер после всех манипуляций
    browser.quit()

# не забываем оставить пустую строку в конце файла
# Out:
# <ipython-input-1-eed84803ff3f>:8: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_class_name("first")
# <ipython-input-1-eed84803ff3f>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input2 = browser.find_element_by_class_name("second")
# <ipython-input-1-eed84803ff3f>:12: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input3 = browser.find_element_by_class_name("third")
# <ipython-input-1-eed84803ff3f>:14: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input4 = browser.find_element_by_css_selector("input:nth-child(11)")
# <ipython-input-1-eed84803ff3f>:16: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input5 = browser.find_element_by_css_selector("input:nth-child(14)")
# ...

# %%
from selenium import webdriver
import time 


link = "http://suninjuly.github.io/find_xpath_form"

try:
    browser = webdriver.Chrome()
    browser.get(link)
    
    input1 = browser.find_element_by_tag_name("input")
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_name("last_name")
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_class_name("city")
    input3.send_keys("Smolensk")
    input4 = browser.find_element_by_id("country")
    input4.send_keys("Russia")
    button = browser.find_element_by_css_selector("button.btn")
    button.click()
    
    button = browser.find_element_by_xpath('//button[text()="Submit"]')
    button.click()

finally:
    # успеваем скопировать код за 30 секунд
    time.sleep(30)
    # закрываем браузер после всех манипуляций
    browser.quit()

# не забываем оставить пустую строку в конце файла
# Out:
# <ipython-input-14-ba6364ff803a>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_tag_name("input")
# <ipython-input-14-ba6364ff803a>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input2 = browser.find_element_by_name("last_name")
# <ipython-input-14-ba6364ff803a>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input3 = browser.find_element_by_class_name("city")
# <ipython-input-14-ba6364ff803a>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input4 = browser.find_element_by_id("country")
# <ipython-input-14-ba6364ff803a>:19: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   button = browser.find_element_by_css_selector("button.btn")
# ...

# %%
from selenium import webdriver
import time

try: 
    link = "http://suninjuly.github.io/registration1.html"
    browser = webdriver.Chrome()
    browser.get(link)

    # Ваш код, который заполняет обязательные поля
    
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")
    
    # Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

    # с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта
    assert "Congratulations! You have successfully registered!" == welcome_text

finally:
    # ожидание чтобы визуально оценить результаты прохождения скрипта
    time.sleep(10)
    # закрываем браузер после всех манипуляций
    browser.quit()
# Out:
# <ipython-input-2-485579cde096>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
# <ipython-input-2-485579cde096>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
# <ipython-input-2-485579cde096>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
# <ipython-input-2-485579cde096>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
# ...

# %%
from selenium import webdriver
import time

try: 
    link = "http://suninjuly.github.io/registration2.html"
    browser = webdriver.Chrome()
    browser.get(link)

    # Ваш код, который заполняет обязательные поля
    
    input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
    input1.send_keys("Ivan")
    input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
    input2.send_keys("Petrov")
    input3 = browser.find_element_by_xpath('//input[@placeholder="Input your email"]')
    input3.send_keys("I@I.ru")
    input4 = browser.find_element_by_xpath('//input[@placeholder="Input your phone:"]')
    input4.send_keys("903")
    input5 = browser.find_element_by_xpath('//input[@placeholder="Input your address:"]')
    input5.send_keys("Hodgepodge street")
    
    # Отправляем заполненную форму
    button = browser.find_element_by_css_selector("button.btn")
    button.click()

    # Проверяем, что смогли зарегистрироваться
    # ждем загрузки страницы
    time.sleep(1)

    # находим элемент, содержащий текст
    welcome_text_elt = browser.find_element_by_tag_name("h1")
    # записываем в переменную welcome_text текст из элемента welcome_text_elt
    welcome_text = welcome_text_elt.text

    # с помощью assert проверяем, что ожидаемый текст совпадает с текстом на странице сайта
    assert "Congratulations! You have successfully registered!" == welcome_text

finally:
    # ожидание чтобы визуально оценить результаты прохождения скрипта
    time.sleep(10)
    # закрываем браузер после всех манипуляций
    browser.quit()
# Out:
# <ipython-input-1-10e46448086c>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-1-10e46448086c> in <module>
#       9     # Ваш код, который заполняет обязательные поля
#      10
# ---> 11     input1 = browser.find_element_by_xpath('//input[@placeholder="Input your first name"]')
#      12     input1.send_keys("Ivan")
#      13     input2 = browser.find_element_by_xpath('//input[@placeholder="Input your last name"]')
#
# c:\dev\jupyter\dist\pyenv3.8-win64\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     518             stacklevel=2,
#     519         )
# --> 520         return self.find_element(by=By.XPATH, value=xpath)
# ...
